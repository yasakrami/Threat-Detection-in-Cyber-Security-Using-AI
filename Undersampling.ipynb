# %%
import pandas as pd
from imblearn.under_sampling import RandomUnderSampler

# List of attack types and BENIGN
attack_types = ["Bot", "DDoS", "DoS GoldenEye", "DoS Hulk", "DoS Slowhttptest", "DoS slowloris", "FTP-Patator",
                "Heartbleed", "Infiltration", "PortScan", "SSH-Patator", "Web Attack  Brute Force",
                "Web Attack  Sql Injection", "Web Attack  XSS"]
benign_type = "BENIGN"
# Loop through each attack type
for attack_type in attack_types:
    # Load the combined data file
    input_filename = f"{attack_type}_vs_{benign_type}.csv"
    combined_data = pd.read_csv(input_filename)
    
    # Separate features (X) and labels (y)
    X = combined_data.drop(columns=[" Label"])
    y = combined_data[" Label"]
    
    # Skip undersampling if the class count is too low
    if len(set(y)) <= 1:
        print(f"Skipping {attack_type}, not enough classes")
        continue
    
    # Perform undersampling using RandomUnderSampler
    sampler = RandomUnderSampler(sampling_strategy=0.5, random_state=42)
    X_resampled, y_resampled = sampler.fit_resample(X, y)
    
    # Create a DataFrame with resampled data
    resampled_data = pd.DataFrame(X_resampled, columns=X.columns)
    resampled_data["Label"] = y_resampled
    
    # Save the resampled data back to the original file
    resampled_data.to_csv(input_filename, index=False)
    print(f"Resampled and replaced {input_filename}")
# Out:
# Resampled and replaced Bot_vs_BENIGN.csv
# Resampled and replaced DDoS_vs_BENIGN.csv
# Resampled and replaced DoS GoldenEye_vs_BENIGN.csv
# Resampled and replaced DoS Hulk_vs_BENIGN.csv
# Resampled and replaced DoS Slowhttptest_vs_BENIGN.csv
# Resampled and replaced DoS slowloris_vs_BENIGN.csv
# Resampled and replaced FTP-Patator_vs_BENIGN.csv
# Resampled and replaced Heartbleed_vs_BENIGN.csv
# Resampled and replaced Infiltration_vs_BENIGN.csv
# Resampled and replaced PortScan_vs_BENIGN.csv
# Resampled and replaced SSH-Patator_vs_BENIGN.csv
# Resampled and replaced Web Attack  Brute Force_vs_BENIGN.csv
# Resampled and replaced Web Attack  Sql Injection_vs_BENIGN.csv
# Resampled and replaced Web Attack  XSS_vs_BENIGN.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Loop through each attack type
for attack_type in attack_types:
    # Load the combined data file
    input_filename = f"{attack_type}_vs_{benign_type}.csv"
    combined_data = pd.read_csv(input_filename)
    
    # Count the number of instances for each class
    class_counts = combined_data[" Label"].value_counts()
    
    # Plot the class distribution
    plt.figure(figsize=(8, 6))
    class_counts.plot(kind="bar", color=["green", "red"])
    plt.title(f"Class Distribution for {attack_type}")
    plt.xlabel("Class")
    plt.ylabel("Count")
    plt.xticks(rotation=45)
    plt.legend(["BENIGN", attack_type])
    plt.tight_layout()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' Label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 10
#       7 combined_data = pd.read_csv(input_filename)
#       9 # Count the number of instances for each class
# ---> 10 class_counts = combined_data[" Label"].value_counts()
#      12 # Plot the class distribution
#      13 plt.figure(figsize=(8, 6))
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: ' Label'

# %%
import pandas as pd
import glob

# List of file names
file_names = [
    'Bot_vs_BENIGN.csv', 'DDoS_vs_BENIGN.csv', 'DoS GoldenEye_vs_BENIGN.csv',
    'DoS Hulk_vs_BENIGN.csv', 'DoS Slowhttptest_vs_BENIGN.csv',
    'DoS slowloris_vs_BENIGN.csv', 'FTP-Patator_vs_BENIGN.csv',
    'Heartbleed_vs_BENIGN.csv', 'Infiltration_vs_BENIGN.csv',
    'PortScan_vs_BENIGN.csv', 'SSH-Patator_vs_BENIGN.csv',
    'Web Attack  Brute Force_vs_BENIGN.csv',
    'Web Attack  Sql Injection_vs_BENIGN.csv', 'Web Attack  XSS_vs_BENIGN.csv'
]

# Loop through each file
for file_name in file_names:
    # Read the file using pandas
    data = pd.read_csv(file_name)
    
    # Count the number of benign and attack instances
    num_benign = (data['Label'] == 'BENIGN').sum()
    num_attack = (data['Label'] != 'BENIGN').sum()
    
    # Print information
    print(f"File: {file_name}")
    print(f"Number of Benign instances: {num_benign}")
    print(f"Number of Attack instances: {num_attack}")
    print("Shape of the dataset:", data.shape)
    print("-----------------------------")
# Out:
# File: Bot_vs_BENIGN.csv
# Number of Benign instances: 3912
# Number of Attack instances: 1956
# Shape of the dataset: (5868, 85)
# -----------------------------
# File: DDoS_vs_BENIGN.csv
# Number of Benign instances: 256050
# Number of Attack instances: 128025
# Shape of the dataset: (384075, 85)
# -----------------------------
# File: DoS GoldenEye_vs_BENIGN.csv
# Number of Benign instances: 20586
# Number of Attack instances: 10293
# Shape of the dataset: (30879, 85)
# -----------------------------
# File: DoS Hulk_vs_BENIGN.csv
# Number of Benign instances: 460248
# Number of Attack instances: 230124
# Shape of the dataset: (690372, 85)
# -----------------------------
# File: DoS Slowhttptest_vs_BENIGN.csv
# Number of Benign instances: 10998
# Number of Attack instances: 5499
# Shape of the dataset: (16497, 85)
# -----------------------------
# File: DoS slowloris_vs_BENIGN.csv
# Number of Benign instances: 11592
# Number of Attack instances: 5796
# Shape of the dataset: (17388, 85)
# -----------------------------
# File: FTP-Patator_vs_BENIGN.csv
# Number of Benign instances: 15870
# Number of Attack instances: 7935
# Shape of the dataset: (23805, 85)
# -----------------------------
# File: Heartbleed_vs_BENIGN.csv
# Number of Benign instances: 22
# Number of Attack instances: 11
# Shape of the dataset: (33, 85)
# -----------------------------
# File: Infiltration_vs_BENIGN.csv
# Number of Benign instances: 72
# Number of Attack instances: 36
# Shape of the dataset: (108, 85)
# -----------------------------
# File: PortScan_vs_BENIGN.csv
# Number of Benign instances: 317608
# Number of Attack instances: 158804
# Shape of the dataset: (476412, 85)
# -----------------------------
# File: SSH-Patator_vs_BENIGN.csv
# Number of Benign instances: 11794
# Number of Attack instances: 5897
# Shape of the dataset: (17691, 85)
# -----------------------------
# File: Web Attack  Brute Force_vs_BENIGN.csv
# Number of Benign instances: 3014
# Number of Attack instances: 1507
# Shape of the dataset: (4521, 85)
# -----------------------------
# File: Web Attack  Sql Injection_vs_BENIGN.csv
# Number of Benign instances: 42
# Number of Attack instances: 21
# Shape of the dataset: (63, 85)
# -----------------------------
# File: Web Attack  XSS_vs_BENIGN.csv
# Number of Benign instances: 1304
# Number of Attack instances: 652
# Shape of the dataset: (1956, 85)
# -----------------------------
